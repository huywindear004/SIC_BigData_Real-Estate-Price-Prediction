# %% [markdown]
# # Random Forest

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import warnings
import numpy as np

from sklearn.preprocessing import LabelEncoder
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
 
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('../../data/batdongsan/numerized/Dat_numerized-dataset.csv')
df = df.dropna()
print(df)
# Out:
#        Unnamed: 0  DienTich  \
# 1               1   29235.0
# 9               9    3000.0
# 10             10      79.2
# 13             13    1200.0
# 14             14      80.0
# ...           ...       ...
# 23879       23879     144.0
# 23880       23880      72.0
# 23883       23883     177.0
# 23887       23887     100.0
# 23889       23889     300.0
#
#                                                   DiaChi  City  District  \
# 1      Hẻm 50, Đường 1/5, Phường B'Lao, Bảo Lộc, Lâm ...  68.0     673.0
# 9                Đường 415, Xã Minh Quang, Ba Vì, Hà Nội   1.0     271.0
# 10     Đường Cổ Nhuế, Thôn Nhuế, Xã Kim Chung, Đông A...   1.0      17.0
# 13                        Xã Suối Hoa, Tân Lạc, Hòa Bình  17.0     155.0
# 14                       Xã Bình Yên, Thạch Thất, Hà Nội   1.0     276.0
# ...                                                  ...   ...       ...
# 23879                 Phường Đề Thám, Cao Bằng, Cao Bằng   4.0      40.0
# 23880             Phường Duyệt Trung, Cao Bằng, Cao Bằng   4.0      40.0
# 23883                 Phường Đề Thám, Cao Bằng, Cao Bằng   4.0      40.0
# 23887  Đường Quốc lộ 37, Phường Sông Hiến, Cao Bằng, ...   4.0      40.0
# 23889                 Phường Đề Thám, Cao Bằng, Cao Bằng   4.0      40.0
#
#              MucGia  MatTien  DuongVao  PhapLy        Lat        Long     Ward
# 1      1.250000e+11    55.00       4.0     1.0  11.538185  107.800136  24826.0
# 9      1.800000e+10    23.50      15.0     1.0  21.067439  105.325855   9700.0
# 10     4.800000e+09     5.45       3.5     1.0  21.133051  105.779133    493.0
# 13     6.000000e+08    25.00       6.0     1.0  20.735805  105.166077   5134.0
# 14     1.280000e+09     5.00       7.0     1.0  21.029954  105.538789   9982.0
# ...             ...      ...       ...     ...        ...         ...      ...
# 23879  3.500000e+09     9.00       7.0     1.0  22.675031  106.225779   1282.0
# 23880  5.900000e+08     4.50       7.0     1.0  22.633334  106.286879   1288.0
# 23883  4.500000e+09    11.00       6.0     1.0  22.671997  106.218518   1282.0
# 23887  1.600000e+09     5.50      10.0     1.0  22.663841  106.234955   1267.0
# 23889  5.800000e+09    15.00       7.0     1.0  22.671997  106.218518   1282.0
#
# [9402 rows x 12 columns]

# %%
# df = df.dropna(subset=['MucGia'])
df["USD"] = (df["MucGia"]/25400).round(2)
# df=df.drop(columns="MucGia")

# %%
df=df.drop(columns=["Unnamed: 0","DiaChi","MucGia","Lat","Long"])

# %%
df.head(5)
# Out:
#     DienTich  City  District  MatTien  DuongVao  PhapLy     Ward         USD
# 1    29235.0  68.0     673.0    55.00       4.0     1.0  24826.0  4921259.84
# 9     3000.0   1.0     271.0    23.50      15.0     1.0   9700.0   708661.42
# 10      79.2   1.0      17.0     5.45       3.5     1.0    493.0   188976.38
# 13    1200.0  17.0     155.0    25.00       6.0     1.0   5134.0    23622.05
# 14      80.0   1.0     276.0     5.00       7.0     1.0   9982.0    50393.70

# %%
# Assuming df is your DataFrame
X = df.iloc[:,0:7].values#features
y = df.iloc[:,7].values# Target variable# Target variable

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder

# Check for and handle categorical variables
label_encoder = LabelEncoder()
x_categorical = df.select_dtypes(include=['object']).apply(label_encoder.fit_transform)
x_numerical = df.select_dtypes(exclude=['object']).values
x = pd.concat([pd.DataFrame(x_numerical), x_categorical], axis=1).values
# Fitting Random Forest Regression to the dataset
regressor = RandomForestRegressor(n_estimators=10, random_state=0, oob_score=True)

# Fit the regressor with x and y data
regressor.fit(x, y)
# Out:
# RandomForestRegressor(n_estimators=10, oob_score=True, random_state=0)

# %%
# Evaluating the model
from sklearn.metrics import mean_squared_error, r2_score

# Access the OOB Score
oob_score = regressor.oob_score_
print(f'Out-of-Bag Score: {oob_score}')

# Making predictions on the same data or new data
predictions = regressor.predict(x)

# Evaluating the model
mse = mean_squared_error(y, predictions)
print(f'Mean Squared Error: {mse}')
r2 = r2_score(y, predictions)
print(f'R-squared: {r2}')
# Out:
# Out-of-Bag Score: 0.012475267757762865
# Mean Squared Error: 2647006025847838.5
# R-squared: 0.7531214855908347

# %% [markdown]
# # Random Forest fill NA with KNN

# %%
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV

# Load data
df = pd.read_csv('../../data/batdongsan/numerized/Dat_numerized-dataset.csv')

# Kiểm tra các giá trị bị thiếu
print(df.isnull().sum())

# Khởi tạo KNN Imputer
imputer = KNNImputer(n_neighbors=5)

# Chọn các cột cần điền giá trị thiếu
columns_to_impute = df.select_dtypes(include=[np.number]).columns

# Điền giá trị thiếu
columns_to_round = ['PhapLy']

# Điền giá trị thiếu
df[columns_to_impute] = imputer.fit_transform(df[columns_to_impute])
df[columns_to_round] = df[columns_to_round].round()
# Kiểm tra lại các giá trị bị thiếu
print(df.isnull().sum())
# Out:
# Unnamed: 0       0
# DienTich         1
# DiaChi           1
# City             1
# District         9
# MucGia        3830
# MatTien       7814
# DuongVao      9159
# PhapLy        4587
# Lat           1655
# Long          1655
# Ward           221
# dtype: int64
# Unnamed: 0    0
# DienTich      0
# DiaChi        1
# City          0
# District      0
# MucGia        0
# MatTien       0
# DuongVao      0
# PhapLy        0
# Lat           0
# Long          0
# Ward          0
# dtype: int64

# %%
df = df.dropna()
print(df)
# Out:
#        Unnamed: 0  DienTich  \
# 0             0.0     180.0
# 1             1.0   29235.0
# 2             2.0     250.0
# 3             3.0      63.0
# 4             4.0    3000.0
# ...           ...       ...
# 23886     23886.0     340.0
# 23887     23887.0     100.0
# 23888     23888.0      72.0
# 23889     23889.0     300.0
# 23890     23890.0    1270.0
#
#                                                   DiaChi  City  District  \
# 0             Đường 768, Xã Tân Bình, Vĩnh Cửu, Đồng Nai  75.0     735.0
# 1      Hẻm 50, Đường 1/5, Phường B'Lao, Bảo Lộc, Lâm ...  68.0     673.0
# 2                   Phường Cô Giang, Quận 1, Hồ Chí Minh  79.0     760.0
# 3      Đường Bạch Thái Bưởi, Phường Đằng Giang, Ngô Q...  31.0     304.0
# 4                             Xã Cẩm Lĩnh, Ba Vì, Hà Nội   1.0     271.0
# ...                                                  ...   ...       ...
# 23886  Đường Quốc Lộ 3, Phường Đề Thám, Cao Bằng, Cao...   4.0      40.0
# 23887  Đường Quốc lộ 37, Phường Sông Hiến, Cao Bằng, ...   4.0      40.0
# 23888                Phường Đề Thám, Cao Bằng, Cao Bằng.   4.0      40.0
# 23889                 Phường Đề Thám, Cao Bằng, Cao Bằng   4.0      40.0
# 23890                 Phường Đề Thám, Cao Bằng, Cao Bằng   4.0      40.0
#
#              MucGia  MatTien  DuongVao  PhapLy        Lat        Long     Ward
# 0      5.169180e+13      5.0       7.0     1.0  11.001454  106.818515  26194.0
# 1      1.250000e+11     55.0       4.0     1.0  11.538185  107.800136  24826.0
# 2      4.500000e+10     11.0       9.8     1.0  10.762480  106.693775  26755.0
# 3      7.875000e+09      4.5       7.6     1.0  20.842289  106.704846  11359.0
# 4      4.500000e+09     22.4       7.4     1.0  20.963505  105.609291   9673.0
# ...             ...      ...       ...     ...        ...         ...      ...
# 23886  5.500000e+09     20.0       7.0     1.0  21.340569  105.944139   1282.0
# 23887  1.600000e+09      5.5      10.0     1.0  22.663841  106.234955   1267.0
# 23888  1.600000e+09      4.5       6.0     1.0  21.959984  106.082545   1282.0
# 23889  5.800000e+09     15.0       7.0     1.0  22.671997  106.218518   1282.0
# 23890  6.000000e+09     28.0       4.0     1.0  21.343223  105.916508   1282.0
#
# [23890 rows x 12 columns]

# %%
# df = df.dropna(subset=['MucGia'])
df["USD"] = (df["MucGia"]/25400).round(2)
# df=df.drop(columns="MucGia")

# %%
df=df.drop(columns=["Unnamed: 0","DiaChi","MucGia","Lat","Long"])

# %%
df.head(5)
# Out:
#    DienTich  City  District  MatTien  DuongVao  PhapLy     Ward           USD
# 0     180.0  75.0     735.0      5.0       7.0     1.0  26194.0  2.035110e+09
# 1   29235.0  68.0     673.0     55.0       4.0     1.0  24826.0  4.921260e+06
# 2     250.0  79.0     760.0     11.0       9.8     1.0  26755.0  1.771654e+06
# 3      63.0  31.0     304.0      4.5       7.6     1.0  11359.0  3.100394e+05
# 4    3000.0   1.0     271.0     22.4       7.4     1.0   9673.0  1.771654e+05

# %%
# Assuming df is your DataFrame
X = df.iloc[:,0:7].values#features
y = df.iloc[:,7].values# Target variable# Target variable
print(y)
# Out:
# [2.03511024e+09 4.92125984e+06 1.77165354e+06 ... 6.29921300e+04
#  2.28346460e+05 2.36220470e+05]

# %%
label_encoder = LabelEncoder()
x_categorical = df.select_dtypes(include=['object']).apply(label_encoder.fit_transform)
x_numerical = df.select_dtypes(exclude=['object']).values
x = pd.concat([pd.DataFrame(x_numerical), x_categorical], axis=1).values

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regressor = RandomForestRegressor(n_estimators=10, random_state=0, oob_score=True)

# Fit the regressor with x and y data
regressor.fit(x, y)
# Out:
# RandomForestRegressor(n_estimators=10, oob_score=True, random_state=0)

# %%
# Evaluating the model
from sklearn.metrics import mean_squared_error, r2_score

# Access the OOB Score
oob_score = regressor.oob_score_
print(f'Out-of-Bag Score: {oob_score}')

# Making predictions on the same data or new data
predictions = regressor.predict(x)

# Evaluating the model
mse = mean_squared_error(y, predictions)
print(f'Mean Squared Error: {mse}')
r2 = r2_score(y, predictions)
print(f'R-squared: {r2}')
# Out:
# Out-of-Bag Score: 0.9748315558056208
# Mean Squared Error: 665578202631136.2
# R-squared: 0.9978203884101958

# %% [markdown]
# # Random Forest fill NA with median value

# %%
from sklearn.impute import SimpleImputer
# Load data
df = pd.read_csv('../../data/batdongsan/numerized/Dat_numerized-dataset.csv')

# Kiểm tra các giá trị bị thiếu
print(df.isnull().sum())
# Khởi tạo SimpleImputer
imputer = SimpleImputer(strategy='mean')
columns_to_round = ['PhapLy']

# Điền giá trị thiếu
df[columns_to_impute] = imputer.fit_transform(df[columns_to_impute])
df[columns_to_round] = df[columns_to_round].round()

# Kiểm tra lại các giá trị bị thiếu
print(df.isnull().sum())

# Các bước tiếp theo tương tự như trên
# Out:
# Unnamed: 0       0
# DienTich         1
# DiaChi           1
# City             1
# District         9
# MucGia        3830
# MatTien       7814
# DuongVao      9159
# PhapLy        4587
# Lat           1655
# Long          1655
# Ward           221
# dtype: int64
# Unnamed: 0    0
# DienTich      0
# DiaChi        1
# City          0
# District      0
# MucGia        0
# MatTien       0
# DuongVao      0
# PhapLy        0
# Lat           0
# Long          0
# Ward          0
# dtype: int64

# %%
df = df.dropna()
print(df)
# Out:
#        Unnamed: 0  DienTich  \
# 0             0.0     180.0
# 1             1.0   29235.0
# 2             2.0     250.0
# 3             3.0      63.0
# 4             4.0    3000.0
# ...           ...       ...
# 23886     23886.0     340.0
# 23887     23887.0     100.0
# 23888     23888.0      72.0
# 23889     23889.0     300.0
# 23890     23890.0    1270.0
#
#                                                   DiaChi  City  District  \
# 0             Đường 768, Xã Tân Bình, Vĩnh Cửu, Đồng Nai  75.0     735.0
# 1      Hẻm 50, Đường 1/5, Phường B'Lao, Bảo Lộc, Lâm ...  68.0     673.0
# 2                   Phường Cô Giang, Quận 1, Hồ Chí Minh  79.0     760.0
# 3      Đường Bạch Thái Bưởi, Phường Đằng Giang, Ngô Q...  31.0     304.0
# 4                             Xã Cẩm Lĩnh, Ba Vì, Hà Nội   1.0     271.0
# ...                                                  ...   ...       ...
# 23886  Đường Quốc Lộ 3, Phường Đề Thám, Cao Bằng, Cao...   4.0      40.0
# 23887  Đường Quốc lộ 37, Phường Sông Hiến, Cao Bằng, ...   4.0      40.0
# 23888                Phường Đề Thám, Cao Bằng, Cao Bằng.   4.0      40.0
# 23889                 Phường Đề Thám, Cao Bằng, Cao Bằng   4.0      40.0
# 23890                 Phường Đề Thám, Cao Bằng, Cao Bằng   4.0      40.0
#
#              MucGia    MatTien  DuongVao  PhapLy        Lat        Long  \
# 0      2.710382e+10   5.000000   7.00000     1.0  11.001454  106.818515
# 1      1.250000e+11  55.000000   4.00000     1.0  11.538185  107.800136
# 2      4.500000e+10  11.000000  10.94797     1.0  10.762480  106.693775
# 3      7.875000e+09   4.500000  10.94797     1.0  20.842289  106.704846
# 4      4.500000e+09  13.257537  10.94797     1.0  15.069132  106.701299
# ...             ...        ...       ...     ...        ...         ...
# 23886  5.500000e+09  20.000000   7.00000     1.0  15.069132  106.701299
# 23887  1.600000e+09   5.500000  10.00000     1.0  22.663841  106.234955
# 23888  1.600000e+09   4.500000   6.00000     1.0  15.069132  106.701299
# 23889  5.800000e+09  15.000000   7.00000     1.0  22.671997  106.218518
# 23890  6.000000e+09  28.000000   4.00000     1.0  15.069132  106.701299
#
#           Ward
# 0      26194.0
# 1      24826.0
# 2      26755.0
# 3      11359.0
# 4       9673.0
# ...        ...
# 23886   1282.0
# 23887   1267.0
# 23888   1282.0
# 23889   1282.0
# 23890   1282.0
#
# [23890 rows x 12 columns]

# %%
# df = df.dropna(subset=['MucGia'])
df["USD"] = (df["MucGia"]/25400).round(2)
# df=df.drop(columns="MucGia")

# %%
df=df.drop(columns=["Unnamed: 0","DiaChi","MucGia","Lat","Long"])

# %%
df.head(5)
# Out:
#    DienTich  City  District    MatTien  DuongVao  PhapLy     Ward         USD
# 0     180.0  75.0     735.0   5.000000   7.00000     1.0  26194.0  1067079.55
# 1   29235.0  68.0     673.0  55.000000   4.00000     1.0  24826.0  4921259.84
# 2     250.0  79.0     760.0  11.000000  10.94797     1.0  26755.0  1771653.54
# 3      63.0  31.0     304.0   4.500000  10.94797     1.0  11359.0   310039.37
# 4    3000.0   1.0     271.0  13.257537  10.94797     1.0   9673.0   177165.35

# %%
# Assuming df is your DataFrame
X = df.iloc[:,0:7].values#features
y = df.iloc[:,7].values# Target variable# Target variable

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder

# Check for and handle categorical variables
label_encoder = LabelEncoder()
x_categorical = df.select_dtypes(include=['object']).apply(label_encoder.fit_transform)
x_numerical = df.select_dtypes(exclude=['object']).values
x = pd.concat([pd.DataFrame(x_numerical), x_categorical], axis=1).values
# Fitting Random Forest Regression to the dataset
regressor = RandomForestRegressor(n_estimators=10, random_state=0, oob_score=True)

# Fit the regressor with x and y data
regressor.fit(x, y)
# Out:
# RandomForestRegressor(n_estimators=10, oob_score=True, random_state=0)

# %%
# Evaluating the model
from sklearn.metrics import mean_squared_error, r2_score

# Access the OOB Score
oob_score = regressor.oob_score_
print(f'Out-of-Bag Score: {oob_score}')

# Making predictions on the same data or new data
predictions = regressor.predict(x)

# Evaluating the model
mse = mean_squared_error(y, predictions)
print(f'Mean Squared Error: {mse}')
r2 = r2_score(y, predictions)
print(f'R-squared: {r2}')
# Out:
# Out-of-Bag Score: 0.03255378189334668
# Mean Squared Error: 1021723024512408.5
# R-squared: 0.7581484082903185
