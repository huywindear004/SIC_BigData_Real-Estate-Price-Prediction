# %%
import os
import pandas as pd

file_path = "/Users/hanbui/Documents/SIC/SIC_BigData_Real-Estate-Price-Prediction/data/batdongsan/numerized/Dat_numerized-dataset.csv"

# Kiểm tra sự tồn tại của tệp trước khi đọc
if os.path.exists(file_path):
    df_ = pd.read_csv(file_path, thousands=',', skipinitialspace=True)
    print(df_.head())
else:
    print("File not found. Please check the file path.")

df = df_.copy()
# Out:
#    Unnamed: 0  DienTich                                             DiaChi  \
# 0           0     180.0         Đường 768, Xã Tân Bình, Vĩnh Cửu, Đồng Nai
# 1           1   29235.0  Hẻm 50, Đường 1/5, Phường B'Lao, Bảo Lộc, Lâm ...
# 2           2     250.0               Phường Cô Giang, Quận 1, Hồ Chí Minh
# 3           3      63.0  Đường Bạch Thái Bưởi, Phường Đằng Giang, Ngô Q...
# 4           4    3000.0                         Xã Cẩm Lĩnh, Ba Vì, Hà Nội
#
#    City  District        MucGia  MatTien  DuongVao  PhapLy        Lat  \
# 0  75.0     735.0           NaN      5.0       7.0     1.0  11.001454
# 1  68.0     673.0  1.250000e+11     55.0       4.0     1.0  11.538185
# 2  79.0     760.0  4.500000e+10     11.0       NaN     NaN  10.762480
# 3  31.0     304.0  7.875000e+09      4.5       NaN     1.0  20.842289
# 4   1.0     271.0  4.500000e+09      NaN       NaN     NaN        NaN
#
#          Long     Ward
# 0  106.818515  26194.0
# 1  107.800136  24826.0
# 2  106.693775  26755.0
# 3  106.704846  11359.0
# 4         NaN   9673.0

# %% [markdown]
# ## Tiền Xử Lí Dữ Liệu

# %%
df.head()
# Out:
#    Unnamed: 0  DienTich                                             DiaChi  \
# 0           0     180.0         Đường 768, Xã Tân Bình, Vĩnh Cửu, Đồng Nai
# 1           1   29235.0  Hẻm 50, Đường 1/5, Phường B'Lao, Bảo Lộc, Lâm ...
# 2           2     250.0               Phường Cô Giang, Quận 1, Hồ Chí Minh
# 3           3      63.0  Đường Bạch Thái Bưởi, Phường Đằng Giang, Ngô Q...
# 4           4    3000.0                         Xã Cẩm Lĩnh, Ba Vì, Hà Nội
#
#    City  District        MucGia  MatTien  DuongVao  PhapLy        Lat  \
# 0  75.0     735.0           NaN      5.0       7.0     1.0  11.001454
# 1  68.0     673.0  1.250000e+11     55.0       4.0     1.0  11.538185
# 2  79.0     760.0  4.500000e+10     11.0       NaN     NaN  10.762480
# 3  31.0     304.0  7.875000e+09      4.5       NaN     1.0  20.842289
# 4   1.0     271.0  4.500000e+09      NaN       NaN     NaN        NaN
#
#          Long     Ward
# 0  106.818515  26194.0
# 1  107.800136  24826.0
# 2  106.693775  26755.0
# 3  106.704846  11359.0
# 4         NaN   9673.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23891 entries, 0 to 23890
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  23891 non-null  int64
#  1   DienTich    23890 non-null  float64
#  2   DiaChi      23890 non-null  object
#  3   City        23890 non-null  float64
#  4   District    23882 non-null  float64
#  5   MucGia      20061 non-null  float64
#  6   MatTien     16077 non-null  float64
#  7   DuongVao    14732 non-null  float64
#  8   PhapLy      19304 non-null  float64
#  9   Lat         22236 non-null  float64
#  10  Long        22236 non-null  float64
#  11  Ward        23670 non-null  float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 2.2+ MB

# %%
print(df.shape)
# Out:
# (23891, 12)

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0       0
# DienTich         1
# DiaChi           1
# City             1
# District         9
# MucGia        3830
# MatTien       7814
# DuongVao      9159
# PhapLy        4587
# Lat           1655
# Long          1655
# Ward           221
# dtype: int64

# %%
df[df.duplicated]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, DienTich, DiaChi, City, District, MucGia, MatTien, DuongVao, PhapLy, Lat, Long, Ward]
# Index: []

# %% [markdown]
# <li>KHÔNG CÓ GIÁ TRỊ TRÙNG LẶP</li>

# %%
selected_columns = ['DienTich','MatTien','DuongVao','MucGia']
statistics = df[selected_columns].describe(percentiles=[0.25, 0.5, 0.7])
print(statistics)
# Out:
#            DienTich       MatTien     DuongVao        MucGia
# count  2.389000e+04  16077.000000  14732.00000  2.006100e+04
# mean   3.174427e+03     13.257537     10.94797  2.710382e+10
# std    1.358244e+05     26.880638     18.28162  1.801642e+12
# min    8.100000e+00      0.380000      0.30000  2.350000e+03
# 25%    8.500000e+01      5.000000      5.00000  1.600000e+09
# 50%    1.360000e+02      6.000000      8.00000  3.700000e+09
# 70%    3.000000e+02     10.000000     12.00000  7.200000e+09
# max    1.500000e+07    818.000000    942.00000  2.550000e+14

# %%
selected_columns = ['DienTich', 'MatTien','DuongVao', 'MucGia']

for i in selected_columns:
    if pd.api.types.is_numeric_dtype(df[i]):
        print(i, 'Min value:', df[i].min(), 'Max value:', df[i].max())
# Out:
# DienTich Min value: 8.1 Max value: 15000000.0
# MatTien Min value: 0.38 Max value: 818.0
# DuongVao Min value: 0.3 Max value: 942.0
# MucGia Min value: 2350.0 Max value: 255000000000000.0

# %% [markdown]
# <span>Diện tích 15 triệu mét vuông và mặt tiền 818 mét là quá lớn<span>

# %%
Q1 = df['DienTich'].quantile(0.25)
Q3 = df['DienTich'].quantile(0.75)
IQR = Q3 - Q1

# Xác định ngưỡng cho các giá trị ngoại lệ
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Lower bound for outliers: {lower_bound}")
print(f"Upper bound for outliers: {upper_bound}")
# Out:
# Lower bound for outliers: -396.5
# Upper bound for outliers: 887.5

# %%
Q1 = df['MatTien'].quantile(0.25)
Q3 = df['MatTien'].quantile(0.75)
IQR = Q3 - Q1

# Xác định ngưỡng cho các giá trị ngoại lệ
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Lower bound for outliers: {lower_bound}")
print(f"Upper bound for outliers: {upper_bound}")
# Out:
# Lower bound for outliers: -4.0
# Upper bound for outliers: 20.0

# %%
Q1 = df['DuongVao'].quantile(0.25)
Q3 = df['DuongVao'].quantile(0.75)
IQR = Q3 - Q1

# Xác định ngưỡng cho các giá trị ngoại lệ
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Lower bound for outliers: {lower_bound}")
print(f"Upper bound for outliers: {upper_bound}")
# Out:
# Lower bound for outliers: -5.5
# Upper bound for outliers: 22.5

# %% [markdown]
# Loại bỏ các cột có giá trị Outliners

# %%
import numpy as np

df['USD'] = round(df['MucGia'] / 24000, 0)


rows = df[df['DienTich'] > 887]
df = df.drop(index=rows.index)


rows = df[df['MatTien'] > 20]
df = df.drop(index=rows.index)

rows = df[df['DuongVao'] > 22]
df = df.drop(index=rows.index)

df = df[df['USD'] > 0]
# Thêm cột log_price bằng cách lấy log của giá trị USD
df['log_price'] = np.log(df['USD'])

# In ra số lượng hàng sau khi làm sạch dữ liệu
print("The number of rows after cleaning data:", len(df))
# Out:
# The number of rows after cleaning data: 15479

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15479 entries, 2 to 23889
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  15479 non-null  int64
#  1   DienTich    15479 non-null  float64
#  2   DiaChi      15479 non-null  object
#  3   City        15479 non-null  float64
#  4   District    15476 non-null  float64
#  5   MucGia      15479 non-null  float64
#  6   MatTien     10960 non-null  float64
#  7   DuongVao    9910 non-null   float64
#  8   PhapLy      12650 non-null  float64
#  9   Lat         14418 non-null  float64
#  10  Long        14418 non-null  float64
#  11  Ward        15346 non-null  float64
#  12  USD         15479 non-null  float64
#  13  log_price   15479 non-null  float64
# dtypes: float64(12), int64(1), object(1)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Trực Quan Dữ Liệu

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Danh sách các cột muốn vẽ biểu đồ
columns_to_plot = ['DienTich', 'MatTien','DuongVao']

num_cols = 3  # Số cột bạn muốn trong lưới subplot
num_rows = (len(columns_to_plot) + num_cols - 1) // num_cols  # Tính số hàng cần thiết
fig, axs = plt.subplots(ncols=num_cols, nrows=num_rows, figsize=(15, 5*num_rows))

axs = axs.flatten()
for i, column in enumerate(columns_to_plot):
    sns.scatterplot(x=column, y='log_price', data=df, ax=axs[i])
    axs[i].set_xlabel(column)
    axs[i].set_ylabel('log_price')
    axs[i].set_title(f'Biểu đồ log_price vs {column}')
    axs[i].set_yticks([5, 10, 15])  # Đặt các bước nhảy cho trục y
    axs[i].grid(True)

# Loại bỏ các trục dư thừa (nếu có)
for i in range(len(columns_to_plot), len(axs)):
    fig.delaxes(axs[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# Ta thấy 3 yếu tố này ảnh hưởng mạnh đến mức giá

# %%
value_counts = df['DiaChi'].value_counts()
print(value_counts)
# Out:
# DiaChi
# Đường 420, Xã Bình Yên, Thạch Thất, Hà Nội                       53
# Xã Lộc An, Bảo Lâm, Lâm Đồng                                     50
# Đường Vườn Lài, Phường An Phú Đông, Quận 12, Hồ Chí Minh         49
# Đường Phúc Lợi, Phường Phúc Lợi, Long Biên, Hà Nội               47
# Xã Phúc Thọ, Lâm Hà, Lâm Đồng                                    41
#                                                                  ..
# Đường Nguyễn Trọng Dân, Xã Long Chánh, Gò Công, Tiền Giang        1
# 2/, Đường Số 6, Phường Bình Hưng Hòa B, Bình Tân, Hồ Chí Minh     1
# Đường Nguyễn Huệ, Phường Lái Hiếu, Ngã Bảy, Hậu Giang             1
# Đường Ba Chả, Xã Hưng Long, Bình Chánh, Hồ Chí Minh               1
# Đường Quốc Lộ 3, Phường Đề Thám, Cao Bằng, Cao Bằng               1
# Name: count, Length: 8258, dtype: int64

# %%
valid_cities = [
    'Hà Nội', 'Hồ Chí Minh', 'Đà Nẵng', 'Cần Thơ', 'Hải Phòng', 'Hạ Long', 'Nha Trang', 
    'Huế', 'Vũng Tàu', 'Biên Hòa', 'Quy Nhơn', 'Pleiku', 'Bình Dương', 'Bạc Liêu', 
    'Cà Mau', 'Sóc Trăng', 'Tây Ninh', 'Bến Tre', 'Long An', 'Tiền Giang', 'Trà Vinh', 
    'Hậu Giang', 'Đồng Tháp', 'An Giang', 'Kiên Giang', 'Vĩnh Long', 'Hà Tĩnh', 
    'Quảng Bình', 'Quảng Trị', 'Lâm Đồng', 'Đắk Lắk', 'Đắk Nông', 'Kon Tum', 'Gia Lai', 
    'Yên Bái', 'Thái Nguyên', 'Bắc Ninh', 'Bắc Giang', 'Hưng Yên', 'Hà Nam', 'Nam Định', 
    'Ninh Bình', 'Thanh Hóa', 'Nghệ An', 'Hòa Bình', 'Lào Cai', 'Tuyên Quang', 
    'Hà Giang', 'Cao Bằng', 'Lạng Sơn', 'Sơn La', 'Điện Biên', 'Hải Dương', 'Vĩnh Phúc', 
    'Hà Tây', 'Hưng Yên', 'Thái Bình', 'Hải Phòng', 'Bắc Kạn', 'Bắc Giang'
]


def extract_city(address):
    parts = address.split(',')
    for part in reversed(parts):
        part = part.strip().replace('.', '')
        if part in valid_cities:
            return part
    return None

# Tạo cột 'city' chứa tên thành phố
df['ThanhPho'] = df['DiaChi'].apply(extract_city)

df.head()
# Out:
#     Unnamed: 0  DienTich                                             DiaChi  \
# 2            2     250.0               Phường Cô Giang, Quận 1, Hồ Chí Minh
# 3            3      63.0  Đường Bạch Thái Bưởi, Phường Đằng Giang, Ngô Q...
# 6            6     420.0  Đường Lê Hoàng Phái, Phường 17, Gò Vấp, Hồ Chí...
# 8            8     205.0              Phường Hòa Hải, Ngũ Hành Sơn, Đà Nẵng
# 10          10      79.2  Đường Cổ Nhuế, Thôn Nhuế, Xã Kim Chung, Đông A...
#
#     City  District        MucGia  MatTien  DuongVao  PhapLy        Lat  \
# 2   79.0     760.0  4.500000e+10    11.00       NaN     NaN  10.762480
# 3   31.0     304.0  7.875000e+09     4.50       NaN     1.0  20.842289
# 6   79.0     764.0  4.600000e+10      NaN       NaN     NaN  10.840956
# 8   48.0     494.0  8.000000e+09    12.00       NaN     1.0        NaN
# 10   1.0      17.0  4.800000e+09     5.45       3.5     1.0  21.133051
#
#           Long     Ward        USD  log_price     ThanhPho
# 2   106.693775  26755.0  1875000.0  14.444119  Hồ Chí Minh
# 3   106.704846  11359.0   328125.0  12.701150    Hải Phòng
# 6   106.675389  26875.0  1916667.0  14.466098  Hồ Chí Minh
# 8          NaN  20290.0   333333.0  12.716897      Đà Nẵng
# 10  105.779133    493.0   200000.0  12.206073       Hà Nội

# %%
district = df['ThanhPho'].value_counts()
district.head(50)
# Out:
# ThanhPho
# Hà Nội         4493
# Hồ Chí Minh    3008
# Đà Nẵng        1102
# Bình Dương      816
# Hải Phòng       610
# Lâm Đồng        493
# Long An         477
# Nha Trang       353
# Tây Ninh        283
# Hưng Yên        206
# Biên Hòa        189
# Thanh Hóa       187
# Bắc Ninh        132
# Hòa Bình        107
# Kiên Giang       96
# Tiền Giang       93
# Vĩnh Phúc        84
# Cần Thơ          72
# Đắk Lắk          71
# Bắc Giang        62
# Nghệ An          53
# Nam Định         53
# Vũng Tàu         52
# Hạ Long          45
# Thái Nguyên      41
# Đồng Tháp        31
# Thái Bình        30
# Hải Dương        25
# Bến Tre          25
# Gia Lai          24
# Hà Nam           19
# Vĩnh Long        19
# Hà Tĩnh          18
# Cao Bằng         17
# Quy Nhơn         14
# Sóc Trăng        13
# Cà Mau           13
# Ninh Bình        13
# Kon Tum          13
# Lào Cai          13
# Trà Vinh         11
# An Giang         11
# Đắk Nông          9
# Bạc Liêu          9
# Hậu Giang         8
# Huế               7
# Sơn La            7
# Quảng Trị         7
# Yên Bái           6
# Quảng Bình        4
# Name: count, dtype: int64

# %% [markdown]
# Tính Tương Quan của các Thành Phố và Giá

# %%
frame1 = df

table = frame1.groupby(['ThanhPho'])['USD'].mean().reset_index()
# Gộp bảng tính giá trị trung bình vào 'frame1'
frame1 = frame1.merge(table, how='left', on='ThanhPho', suffixes=('', '_mean'))

# Chỉ định nhãn cho 3 nhóm 'Low', 'Medium', 'High'
labels = ['Low', 'Medium', 'High']

# Tạo các nhóm giá trị USD với qcut
num_bins = 3  # Số lượng nhóm bạn muốn chia
frame1['range'] = pd.qcut(frame1['USD_mean'], q=num_bins, labels=labels, duplicates='drop')

# Thiết lập kích thước hình vẽ
plt.rcParams['figure.figsize'] = (18, 8)

# Tạo DataFrame để vẽ biểu đồ
df_plot = frame1.groupby(['ThanhPho', 'range'], observed=False)['USD'].mean().unstack(fill_value=0)
df_plot.plot(kind='bar')

# Thiết lập tiêu đề cho biểu đồ
plt.title('Thành Phố Và Giá')
plt.show()

# %%
pl = df['PhapLy'].value_counts()
pl.head(50)
# Không sổ : 0
# - Đã có sổ: 1
# - Đang chờ sổ: 2
# - Sổ chung | công chứng vi bằng: 3
# - viết tay: 4
# Out:
# PhapLy
# 1.0    12494
# 2.0       76
# 4.0       57
# 0.0       18
# 3.0        5
# Name: count, dtype: int64

# %%
legal = {0.0 :'không sổ', 1.0 : 'đã có sổ', 2.0 : 'đang chờ sổ', 3.0 : 'Sổ chung | công chứng vi bằng', 4.0 : 'viết tay' }

df['legal'] = df['PhapLy'].map(legal)

# %%
# Giả sử 'df' là DataFrame ban đầu của bạn
frame1 = df

# Tính giá trị trung bình của USD theo nhóm trong cột 'TinhTrangBDS'
col = 'legal'
table = frame1.groupby([col])['USD'].mean().reset_index()
# Gộp bảng tính giá trị trung bình vào 'frame1'
frame1 = frame1.merge(table, how='left', on=col, suffixes=('', '_mean'))

# Chỉ định nhãn cho 2 nhóm 'Low' và 'High'
labels = ['Low', 'Medium','High']

# Chuyển đổi Series thành mảng NumPy một chiều và áp dụng pd.cut
frame1['range'] = pd.cut(frame1['USD_mean'].to_numpy(), bins=3, labels=labels)

# Thiết lập kích thước hình vẽ
plt.rcParams['figure.figsize'] = (18, 8)

# Tạo DataFrame để vẽ biểu đồ
df_plot = frame1.groupby([col, 'range'], observed=False)['USD'].mean().unstack(fill_value=0)
df_plot.plot(kind='bar')

# Thiết lập tiêu đề cho biểu đồ
plt.title('Pháp Lý và Giá')
plt.show()

# %% [markdown]
# Như ta thấy thì nếu sổ chung hoặc đang chờ sổ giá sẽ kh cao bằng đã có sổ

# %%
# Kiểm tra giá trị NaN trong DataFrame
nan_values = df.isna()

# Xác định các cột có chứa giá trị NaN
nan_columns = nan_values.any()

# Lấy danh sách các cột có giá trị NaN
columns_with_nan = df.columns[nan_columns].tolist()

# Hiển thị danh sách các cột có giá trị NaN
print("Các cột có giá trị NaN:", columns_with_nan)
# Out:
# Các cột có giá trị NaN: ['District', 'MatTien', 'DuongVao', 'PhapLy', 'Lat', 'Long', 'Ward', 'ThanhPho', 'legal']

# %%
df.isna().sum()/df.shape[0]*100
# Out:
# Unnamed: 0     0.000000
# DienTich       0.000000
# DiaChi         0.000000
# City           0.000000
# District       0.019381
# MucGia         0.000000
# MatTien       29.194392
# DuongVao      35.977776
# PhapLy        18.276374
# Lat            6.854448
# Long           6.854448
# Ward           0.859229
# USD            0.000000
# log_price      0.000000
# ThanhPho      12.487887
# legal         18.276374
# dtype: float64

# %%
per =0.5
# Chọn xóa những cột dữ liệu có trên 50% data là NaN
df_dropped = df.dropna(axis=1, thresh=int(df.shape[0] * per))

# Xóa những hàng có bất kỳ giá trị NaN nào
df_dropped_2 = df_dropped.dropna(how='any')

# Hiển thị DataFrame sau khi xóa
df_dropped_2
# Out:
#        Unnamed: 0  DienTich  \
# 10             10      79.2
# 14             14      80.0
# 17             17     129.5
# 45             45      51.0
# 49             49      60.0
# ...           ...       ...
# 23879       23879     144.0
# 23880       23880      72.0
# 23883       23883     177.0
# 23887       23887     100.0
# 23889       23889     300.0
#
#                                                   DiaChi  City  District  \
# 10     Đường Cổ Nhuế, Thôn Nhuế, Xã Kim Chung, Đông A...   1.0      17.0
# 14                       Xã Bình Yên, Thạch Thất, Hà Nội   1.0     276.0
# 17     Hẻm 54, Phố Lý Thường Kiệt, Phường 1, Bảo Lộc,...  68.0     673.0
# 45     Phố An Trung, Phường An Hải Tây, Sơn Trà, Đà Nẵng  48.0     493.0
# 49          Đường 352, Xã Kỳ Sơn, Thủy Nguyên, Hải Phòng  31.0     311.0
# ...                                                  ...   ...       ...
# 23879                 Phường Đề Thám, Cao Bằng, Cao Bằng   4.0      40.0
# 23880             Phường Duyệt Trung, Cao Bằng, Cao Bằng   4.0      40.0
# 23883                 Phường Đề Thám, Cao Bằng, Cao Bằng   4.0      40.0
# 23887  Đường Quốc lộ 37, Phường Sông Hiến, Cao Bằng, ...   4.0      40.0
# 23889                 Phường Đề Thám, Cao Bằng, Cao Bằng   4.0      40.0
#
#              MucGia  MatTien  DuongVao  PhapLy        Lat        Long  \
# 10     4.800000e+09     5.45       3.5     1.0  21.133051  105.779133
# 14     1.280000e+09     5.00       7.0     1.0  21.029954  105.538789
# 17     2.550000e+09     5.00       6.0     1.0  11.560026  107.810536
# 45     3.250000e+09     5.00       5.5     1.0  16.060609  108.232746
# 49     2.950000e+08     4.50       5.0     1.0  20.995883  106.602085
# ...             ...      ...       ...     ...        ...         ...
# 23879  3.500000e+09     9.00       7.0     1.0  22.675031  106.225779
# 23880  5.900000e+08     4.50       7.0     1.0  22.633334  106.286879
# 23883  4.500000e+09    11.00       6.0     1.0  22.671997  106.218518
# 23887  1.600000e+09     5.50      10.0     1.0  22.663841  106.234955
# 23889  5.800000e+09    15.00       7.0     1.0  22.671997  106.218518
#
#           Ward       USD  log_price   ThanhPho     legal
# 10       493.0  200000.0  12.206073     Hà Nội  đã có sổ
# 14      9982.0   53333.0  10.884311     Hà Nội  đã có sổ
# 17     24823.0  106250.0  11.573550   Lâm Đồng  đã có sổ
# 45     20278.0  135417.0  11.816114    Đà Nẵng  đã có sổ
# 49     11482.0   12292.0   9.416704  Hải Phòng  đã có sổ
# ...        ...       ...        ...        ...       ...
# 23879   1282.0  145833.0  11.890217   Cao Bằng  đã có sổ
# 23880   1288.0   24583.0  10.109810   Cao Bằng  đã có sổ
# 23883   1282.0  187500.0  12.141534   Cao Bằng  đã có sổ
# 23887   1267.0   66667.0  11.107465   Cao Bằng  đã có sổ
# 23889   1282.0  241667.0  12.395316   Cao Bằng  đã có sổ
#
# [6438 rows x 16 columns]

# %%
# Trích xuất các cột từ 1 đến 8
df_temp = df_dropped_2.iloc[:, 1:9]

# Loại bỏ cột "Giá" và "Địa chỉ" từ phần DataFrame đã trích xuất
df_x = df_temp.drop(columns=['MucGia', 'DiaChi'])

# Hiển thị DataFrame df_x
df_x
# Out:
#        DienTich  City  District  MatTien  DuongVao  PhapLy
# 10         79.2   1.0      17.0     5.45       3.5     1.0
# 14         80.0   1.0     276.0     5.00       7.0     1.0
# 17        129.5  68.0     673.0     5.00       6.0     1.0
# 45         51.0  48.0     493.0     5.00       5.5     1.0
# 49         60.0  31.0     311.0     4.50       5.0     1.0
# ...         ...   ...       ...      ...       ...     ...
# 23879     144.0   4.0      40.0     9.00       7.0     1.0
# 23880      72.0   4.0      40.0     4.50       7.0     1.0
# 23883     177.0   4.0      40.0    11.00       6.0     1.0
# 23887     100.0   4.0      40.0     5.50      10.0     1.0
# 23889     300.0   4.0      40.0    15.00       7.0     1.0
#
# [6438 rows x 6 columns]

# %% [markdown]
# tiền Việt quá lớn nên sẽ dùng tiền USD để tính

# %%
df_y = df_dropped_2.iloc[:, 12]
df_y
# Out:
# 10       200000.0
# 14        53333.0
# 17       106250.0
# 45       135417.0
# 49        12292.0
#            ...
# 23879    145833.0
# 23880     24583.0
# 23883    187500.0
# 23887     66667.0
# 23889    241667.0
# Name: USD, Length: 6438, dtype: float64

# %%
import matplotlib.pyplot as plt

# Dữ liệu mẫu
x = df_x['DienTich']
y = df_y

# Vẽ biểu đồ phân tán
plt.scatter(x, y, color='blue', alpha=0.7)

# Thêm nhãn và tiêu đề
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Simple Scatter Plot')

# Hiển thị biểu đồ
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(df_y, bins=30)
plt.title("Histogram of df_y")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled = scaler.fit_transform(df_x)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(scaled)
X_pca
plt.scatter(X_pca[:,0], X_pca[:,1])
plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler


# Khởi tạo StandardScaler
scaler = StandardScaler()

# Tính toán các tham số chuẩn hóa từ dữ liệu
scaler.fit(df_x)

# Chuyển đổi dữ liệu theo tham số chuẩn hóa
data_preprocessed = scaler.transform(df_x)

# Chuyển đổi kết quả thành DataFrame để dễ đọc
data_preprocessed_df = pd.DataFrame(data_preprocessed, columns=df_x.columns)

# Hiển thị DataFrame đã được chuẩn hóa
print(data_preprocessed_df)
# Out:
#       DienTich      City  District   MatTien  DuongVao    PhapLy
# 0    -0.522895 -1.227640 -1.477696 -0.376666 -1.031160 -0.095546
# 1    -0.516751 -1.227640 -0.592611 -0.514349 -0.249339 -0.095546
# 2    -0.136565  0.789469  0.764063 -0.514349 -0.472716 -0.095546
# 3    -0.739486  0.187347  0.148946 -0.514349 -0.584405 -0.095546
# 4    -0.670361 -0.324457 -0.473005 -0.667332 -0.696094 -0.095546
# ...        ...       ...       ...       ...       ...       ...
# 6433 -0.025197 -1.137322 -1.399098  0.709508 -0.249339 -0.095546
# 6434 -0.578195 -1.137322 -1.399098 -0.667332 -0.249339 -0.095546
# 6435  0.228260 -1.137322 -1.399098  1.321437 -0.472716 -0.095546
# 6436 -0.363140 -1.137322 -1.399098 -0.361367  0.420793 -0.095546
# 6437  1.172964 -1.137322 -1.399098  2.545294 -0.249339 -0.095546
#
# [6438 rows x 6 columns]

# %% [markdown]
# ## Áp Mô Hình

# %% [markdown]
# <li>Data lưu trong 'df'</li>
# <li>Tập x lưu trong 'data_preprocessed'</li>
# <li>Tập y lưu trong 'df_y'</li>

# %% [markdown]
# <h1>1. Train test split</h1>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# 80% train , 20% test
X_train, X_test, y_train, y_test = train_test_split(data_preprocessed, df_y, test_size = 0.2, random_state = 0)# X: Dữ liệu huấn luyện (features)
# X_test: Dữ liệu kiểm tra (features)
# Y: Nhãn huấn luyện (target)
# Y_test: Nhãn kiểm tra (target)
print(X_train.shape, X_test.shape)
# Out:
# (5150, 6) (1288, 6)

# %%
import pandas as pd
import numpy as np

# Giả sử data_preprocessed là numpy.ndarray
# Tạo DataFrame từ numpy.ndarray
df_preprocessed = pd.DataFrame(data_preprocessed, columns=['DienTich', 'City', 'District' ,  'MatTien',  'DuongVao'  ,  'PhapLy']) # Thay 'Column1', 'Column2', 'Column3' bằng tên cột thực tế của bạn

# Kiểm tra giá trị thiếu
missing_values = df_preprocessed.isnull().sum()
print("Số lượng giá trị thiếu trong mỗi cột:")
print(missing_values)

# Tổng số giá trị thiếu
total_missing = missing_values.sum()
print(f"Tổng số giá trị thiếu: {total_missing}")

# Phần trăm giá trị thiếu
missing_percentage = (missing_values / len(df_preprocessed)) * 100
print("Phần trăm giá trị thiếu trong mỗi cột:")
print(missing_percentage)
# Out:
# Số lượng giá trị thiếu trong mỗi cột:
# DienTich    0
# City        0
# District    0
# MatTien     0
# DuongVao    0
# PhapLy      0
# dtype: int64
# Tổng số giá trị thiếu: 0
# Phần trăm giá trị thiếu trong mỗi cột:
# DienTich    0.0
# City        0.0
# District    0.0
# MatTien     0.0
# DuongVao    0.0
# PhapLy      0.0
# dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Vẽ biểu đồ phân phối cho từng cột
for column in df_preprocessed.columns:
    plt.figure(figsize=(10, 4))
    sns.boxplot(x=df_preprocessed[column])
    plt.title(f"Boxplot cho cột {column}")
    plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import numpy as np

# Thêm một cột hằng số cho tính toán VIF
X = np.c_[np.ones(df_preprocessed.shape[0]), df_preprocessed]

# Tính toán VIF cho mỗi đặc trưng
vif_data = pd.DataFrame()
vif_data["Feature"] = ['Intercept'] + list(df_preprocessed.columns)
vif_data["VIF"] = [variance_inflation_factor(X, i) for i in range(X.shape[1])]

print("VIF của các đặc trưng:")
print(vif_data)
# Out:
# VIF của các đặc trưng:
#      Feature        VIF
# 0  Intercept   1.000000
# 1   DienTich   2.045561
# 2       City  14.209924
# 3   District  14.186469
# 4    MatTien   1.997280
# 5   DuongVao   1.071839
# 6     PhapLy   1.001310

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# Vẽ biểu đồ phân tán giữa từng đặc trưng và biến mục tiêu
for column in df_preprocessed.columns:
    plt.figure(figsize=(10, 4))
    sns.scatterplot(x=df_preprocessed[column], y=df_y)
    plt.title(f"Biểu đồ phân tán giữa {column} và giá")
    plt.xlabel(column)
    plt.ylabel('Giá')

    # Đảm bảo trục y không sử dụng định dạng khoa học
    plt.ticklabel_format(axis='y', style='plain')
    
    # Định dạng trục y nếu cần
    plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x:,.0f}'))

    # Đặt giới hạn trục y
    plt.ylim(0, 2500000)

    plt.show()

# %% [markdown]
# NHẬN XÉT: Biểu đồ phân tán cho thấy chúng không đi theo một trục nhất định, nên ta không thể dùng mô hình Linear Regesstion

# %%
from sklearn.decomposition import PCA

# Chuyển đổi dữ liệu
pca = PCA(n_components=5)  # Giữ lại số lượng đặc trưng tối ưu
X_pca = pca.fit_transform(df_preprocessed)

# Tạo DataFrame từ dữ liệu PCA
df_pca = pd.DataFrame(X_pca, columns=[f'PC{i+1}' for i in range(X_pca.shape[1])])

# %%
from sklearn.ensemble import RandomForestRegressor

# Khởi tạo và huấn luyện mô hình Random Forest
rf = RandomForestRegressor(n_estimators=100, random_state=0)
rf.fit(df_preprocessed, df_y)

# Lấy tầm quan trọng của các đặc trưng
importances = rf.feature_importances_

# Tạo DataFrame để hiển thị tầm quan trọng
importance_df = pd.DataFrame({'Feature': df_preprocessed.columns, 'Importance': importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)
print("Tầm quan trọng của các đặc trưng:")
print(importance_df)
# Out:
# Tầm quan trọng của các đặc trưng:
#     Feature  Importance
# 0  DienTich    0.467475
# 4  DuongVao    0.194194
# 3   MatTien    0.156074
# 2  District    0.154944
# 1      City    0.026516
# 5    PhapLy    0.000797

# %%
from sklearn.feature_selection import SelectKBest, f_regression

# Chọn số lượng đặc trưng để giữ lại
kbest = SelectKBest(score_func=f_regression, k='all')
fit = kbest.fit(df_preprocessed, df_y)

# Lấy điểm số của các đặc trưng
scores = fit.scores_
kbest_df = pd.DataFrame({'Feature': df_preprocessed.columns, 'Score': scores})
kbest_df = kbest_df.sort_values(by='Score', ascending=False)
print("Điểm số của các đặc trưng:")
print(kbest_df)
# Out:
# Điểm số của các đặc trưng:
#     Feature       Score
# 3   MatTien  168.558087
# 0  DienTich  124.949432
# 4  DuongVao   85.404356
# 2  District    9.493935
# 1      City    5.017194
# 5    PhapLy    0.994886

# %% [markdown]
# Như đã thấy thì yếu tố quan trọng nhất là Mặt tiền, Diện Tích và Đường vào

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Khởi tạo mô hình KNN với k = 5
knn = KNeighborsRegressor(n_neighbors=5)

# %%
# Huấn luyện mô hình
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
# Dự đoán
y_pred = knn.predict(X_test)
 
# Tính toán MSE và R2
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"KNN MSE: {mse}") 
print(f"KNN R2: {r2}")
# Out:
# KNN MSE: 428572040049.47107
# KNN R2: -0.039887034333963456

# %%
y_pred
# Out:
# array([ 207206.8,  812333.4,  466666.6, ...,  111000.2,  145565. ,
#        1318300. ])

# %% [markdown]
# <h1>2. Linear Regression</h1>

# %% [markdown]
# <h1>3. Decision Tree Regressor</h1>

# %% [markdown]
# <h1>4. Random Forest Regressor</h1>

# %%
df_x
# Out:
#        DienTich  City  District  MatTien  DuongVao  PhapLy
# 10         79.2   1.0      17.0     5.45       3.5     1.0
# 14         80.0   1.0     276.0     5.00       7.0     1.0
# 17        129.5  68.0     673.0     5.00       6.0     1.0
# 45         51.0  48.0     493.0     5.00       5.5     1.0
# 49         60.0  31.0     311.0     4.50       5.0     1.0
# ...         ...   ...       ...      ...       ...     ...
# 23879     144.0   4.0      40.0     9.00       7.0     1.0
# 23880      72.0   4.0      40.0     4.50       7.0     1.0
# 23883     177.0   4.0      40.0    11.00       6.0     1.0
# 23887     100.0   4.0      40.0     5.50      10.0     1.0
# 23889     300.0   4.0      40.0    15.00       7.0     1.0
#
# [6438 rows x 6 columns]

# %%
X = data_preprocessed
y = df_y

# %%
regressor = RandomForestRegressor(n_estimators=100, random_state=0, oob_score=True)

# Huấn luyện mô hình
regressor.fit(data_preprocessed, y)
# Out:
# RandomForestRegressor(oob_score=True, random_state=0)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Access the OOB Score
oob_score = regressor.oob_score_
print(f'Out-of-Bag Score: {oob_score}')

# Making predictions on the same data or new data
predictions = regressor.predict(data_preprocessed)

# Evaluating the model
mse = mean_squared_error(y, predictions)
print(f'Mean Squared Error: {mse}')

r2 = r2_score(y, predictions)
print(f'R-squared: {r2}')
# Out:
# Out-of-Bag Score: -0.02312044957857773
# Mean Squared Error: 199869130392.51172
# R-squared: 0.8598955132578787

# %% [markdown]
# Nhận xét: Mô hình RandomForestRegressor của bạn có R-squared khá tốt (0.86), cho thấy mô hình giải thích được phần lớn biến thiên trong dữ liệu mục tiêu. Tuy nhiên, điểm số OOB âm (-0.023) và MSE rất lớn (199,869,130,392) cho thấy mô hình còn cần cải thiện

# %%
df_y
# Out:
# 10       200000.0
# 14        53333.0
# 17       106250.0
# 45       135417.0
# 49        12292.0
#            ...
# 23879    145833.0
# 23880     24583.0
# 23883    187500.0
# 23887     66667.0
# 23889    241667.0
# Name: USD, Length: 6438, dtype: float64

# %% [markdown]
# <h1>5. KNN</h1>

# %%
df
# Out:
#        DienTich  City  District  MatTien  DuongVao  PhapLy     Ward  \
# 2         250.0  79.0     760.0    11.00       NaN     NaN  26755.0
# 3          63.0  31.0     304.0     4.50       NaN     1.0  11359.0
# 6         420.0  79.0     764.0      NaN       NaN     NaN  26875.0
# 8         205.0  48.0     494.0    12.00       NaN     1.0  20290.0
# 10         79.2   1.0      17.0     5.45       3.5     1.0    493.0
# ...         ...   ...       ...      ...       ...     ...      ...
# 23885      72.0   4.0      40.0      NaN       NaN     NaN   1282.0
# 23886     340.0   4.0      40.0    20.00       7.0     1.0   1282.0
# 23887     100.0   4.0      40.0     5.50      10.0     1.0   1267.0
# 23888      72.0   4.0      40.0     4.50       6.0     1.0   1282.0
# 23889     300.0   4.0      40.0    15.00       7.0     1.0   1282.0
#
#               USD  log_price     ThanhPho     legal
# 2      1771653.54  14.444119  Hồ Chí Minh       NaN
# 3       310039.37  12.701150    Hải Phòng  đã có sổ
# 6      1811023.62  14.466098  Hồ Chí Minh       NaN
# 8       314960.63  12.716897      Đà Nẵng  đã có sổ
# 10      188976.38  12.206073       Hà Nội  đã có sổ
# ...           ...        ...          ...       ...
# 23885    62992.13  11.107465     Cao Bằng       NaN
# 23886   216535.43  12.342206     Cao Bằng  đã có sổ
# 23887    62992.13  11.107465     Cao Bằng  đã có sổ
# 23888    62992.13  11.107465     Cao Bằng  đã có sổ
# 23889   228346.46  12.395316     Cao Bằng  đã có sổ
#
# [15479 rows x 11 columns]

# %%
filtered_df = df_dropped_2[df_dropped_2['City'] == 79.0]

print(filtered_df)
# Out:
#        Unnamed: 0  DienTich  \
# 54             54      58.0
# 84             84      58.0
# 86             86      88.6
# 179           179      56.0
# 187           187     785.0
# ...           ...       ...
# 23691       23691     137.8
# 23795       23795      80.0
# 23828       23828     120.0
# 23839       23839      58.5
# 23851       23851      96.0
#
#                                                   DiaChi  City  District  \
# 54     Đường Quốc Lộ 13, Phường Hiệp Bình Phước, Thủ ...  79.0     762.0
# 84     Đường Hiệp Bình, Phường Hiệp Bình Phước, Thủ Đ...  79.0     762.0
# 86                  Phường An Lạc, Bình Tân, Hồ Chí Minh  79.0     777.0
# 179    Đường Hồ Học Lãm, Phường An Lạc, Bình Tân, Hồ ...  79.0     777.0
# 187    Đường Thạnh Mỹ Lợi, Phường  Thạnh Mỹ Lợi, Quận...  79.0     769.0
# ...                                                  ...   ...       ...
# 23691  Đường Đào Sư Tích, Xã Phước Kiển, Nhà Bè, Hồ C...  79.0     786.0
# 23795  Đường Bưng Ông Thoàn, Phường Phú Hữu, Quận 9, ...  79.0     763.0
# 23828  Đường Nguyễn Thị Thập, Phường Bình Thuận, Quận...  79.0     778.0
# 23839   Đường 11, Phường Linh Xuân, Thủ Đức, Hồ Chí Minh  79.0     762.0
# 23851  Đường Thạnh Lộc 13, Phường Thạnh Lộc, Quận 12,...  79.0     761.0
#
#              MucGia  MatTien  DuongVao  PhapLy        Lat        Long  \
# 54     4.400000e+09     4.00       5.0     1.0  10.845676  106.718154
# 84     4.200000e+09     8.00       7.0     1.0  10.846008  106.724090
# 86     5.936200e+09     4.05      12.0     1.0  10.726479  106.612036
# 179    3.640000e+09     4.00      12.0     1.0  10.722714  106.610692
# 187    4.500000e+10     8.00       5.0     1.0  10.778965  106.761347
# ...             ...      ...       ...     ...        ...         ...
# 23691  8.000000e+09     6.50      10.0     1.0  10.711343  106.693610
# 23795  4.000000e+09     5.00       8.0     1.0  10.807484  106.798356
# 23828  1.000000e+10     5.80       8.0     1.0  10.738003  106.722903
# 23839  3.200000e+09     4.00       5.0     1.0  10.886328  106.768192
# 23851  5.350000e+09     5.00      11.0     1.0  10.868741  106.685882
#
#           Ward        USD  log_price     ThanhPho     legal
# 54     26809.0   183333.0  12.119059  Hồ Chí Minh  đã có sổ
# 84     26809.0   175000.0  12.072541  Hồ Chí Minh  đã có sổ
# 86     27460.0   247342.0  12.418527  Hồ Chí Minh  đã có sổ
# 179    27460.0   151667.0  11.929443  Hồ Chí Minh  đã có sổ
# 187    27112.0  1875000.0  14.444119  Hồ Chí Minh  đã có sổ
# ...        ...        ...        ...          ...       ...
# 23691  27646.0   333333.0  12.716897  Hồ Chí Minh  đã có sổ
# 23795  26866.0   166667.0  12.023753  Hồ Chí Minh  đã có sổ
# 23828  27478.0   416667.0  12.940043  Hồ Chí Minh  đã có sổ
# 23839  26794.0   133333.0  11.800605  Hồ Chí Minh  đã có sổ
# 23851  26767.0   222917.0  12.314555  Hồ Chí Minh  đã có sổ
#
# [1344 rows x 16 columns]

# %%
# data mới chỉ chứa HCM lưu trong filtered_df

df_new = filtered_df.drop(columns=(['PhapLy','Unnamed: 0','ThanhPho','legal','log_price','Ward','Lat','Long','MucGia','DiaChi']))
df_new
# Out:
#        DienTich  City  District  MatTien  DuongVao        USD
# 54         58.0  79.0     762.0     4.00       5.0   183333.0
# 84         58.0  79.0     762.0     8.00       7.0   175000.0
# 86         88.6  79.0     777.0     4.05      12.0   247342.0
# 179        56.0  79.0     777.0     4.00      12.0   151667.0
# 187       785.0  79.0     769.0     8.00       5.0  1875000.0
# ...         ...   ...       ...      ...       ...        ...
# 23691     137.8  79.0     786.0     6.50      10.0   333333.0
# 23795      80.0  79.0     763.0     5.00       8.0   166667.0
# 23828     120.0  79.0     778.0     5.80       8.0   416667.0
# 23839      58.5  79.0     762.0     4.00       5.0   133333.0
# 23851      96.0  79.0     761.0     5.00      11.0   222917.0
#
# [1344 rows x 6 columns]

# %%
df_X = df_new.drop(columns=(['USD','City']))
df_Y = df_new[['USD']]

# %%
df_X
# Out:
#        DienTich  District  MatTien  DuongVao
# 54         58.0     762.0     4.00       5.0
# 84         58.0     762.0     8.00       7.0
# 86         88.6     777.0     4.05      12.0
# 179        56.0     777.0     4.00      12.0
# 187       785.0     769.0     8.00       5.0
# ...         ...       ...      ...       ...
# 23691     137.8     786.0     6.50      10.0
# 23795      80.0     763.0     5.00       8.0
# 23828     120.0     778.0     5.80       8.0
# 23839      58.5     762.0     4.00       5.0
# 23851      96.0     761.0     5.00      11.0
#
# [1344 rows x 4 columns]

# %%
df_Y
# Out:
#              USD
# 54      183333.0
# 84      175000.0
# 86      247342.0
# 179     151667.0
# 187    1875000.0
# ...          ...
# 23691   333333.0
# 23795   166667.0
# 23828   416667.0
# 23839   133333.0
# 23851   222917.0
#
# [1344 rows x 1 columns]

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score

X_train, X_test, y_train, y_test = train_test_split(df_X, df_Y, test_size = 0.2, random_state = 0)
knn = KNeighborsRegressor(n_neighbors=5)

knn.fit(X_train, y_train.values.ravel())
# Dự đoán
y_pred = knn.predict(X_test)

# Tính toán MSE và R2
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"KNN MSE: {mse}")
print(f"KNN R2: {r2}")
# Out:
# KNN MSE: 69015567893.17339
# KNN R2: 0.37052024193147004
