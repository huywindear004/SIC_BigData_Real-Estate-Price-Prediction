# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab

# %%
df_chungcu = pd.read_csv('../data/test/dataset_chungcu.csv')
df_chungcu.head(5)
# Out:
#                                               DiaChi            Quan  \
# 0  Đường Nguyễn Văn Quỳ, Phường Phú Thuận, Quận 7...          Quận 7
# 1  Đường Nguyễn Văn Linh, Phường Tân Thuận Tây, Q...          Quận 7
# 2  Đường Võ Văn Kiệt, Phường An Lạc, Quận Bình Tâ...   Quận Bình Tân
# 3  108, Đường Hồng Hà, Phường 2, Quận Tân Bình, T...   Quận Tân Bình
# 4  Đường Hậu Giang, Phường 11, Quận 6, Tp Hồ Chí ...          Quận 6
#
#     TinhTrangBDS  DienTich  Phongngu TenPhanKhu  SoTang  PhongTam      Loai  \
# 0    Đã bàn giao      62.0       2.0        NaN     NaN       2.0  Chung cư
# 1    Đã bàn giao      95.0       3.0        NaN     NaN       2.0  Chung cư
# 2  Chưa bàn giao      75.0       2.0          2     5.0       2.0  Chung cư
# 3    Đã bàn giao      70.0       1.0          A     7.0       1.0  Chung cư
# 4    Đã bàn giao      83.0       2.0        NaN     NaN       2.0  Chung cư
#
#          GiayTo     MaCanHo  TinhTrangNoiThat HuongCuaChinh HuongBanCong  \
# ...

# %%
df_chungcu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24019 entries, 0 to 24018
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DiaChi            24019 non-null  object
#  1   Quan              24019 non-null  object
#  2   TinhTrangBDS      24017 non-null  object
#  3   DienTich          24019 non-null  float64
#  4   Phongngu          24019 non-null  float64
#  5   TenPhanKhu        6865 non-null   object
#  6   SoTang            6529 non-null   float64
#  7   PhongTam          24019 non-null  float64
#  8   Loai              24019 non-null  object
#  9   GiayTo            18286 non-null  object
#  10  MaCanHo           3281 non-null   object
#  11  TinhTrangNoiThat  12420 non-null  object
#  12  HuongCuaChinh     9167 non-null   object
#  13  HuongBanCong      8502 non-null   object
#  14  DacDiem           5431 non-null   object
#  15  Gia               24019 non-null  float64
# ...

# %%
df_chungcu['HuongBanCong'].value_counts()
# Out:
# HuongBanCong
# Đông Nam    1939
# Tây Nam     1118
# Tây Bắc     1092
# Đông Bắc    1046
# Đông         982
# Bắc          935
# Tây          712
# Nam          678
# Name: count, dtype: int64

# %%
df_chungcu['Quan'].value_counts()
# Out:
# Quan
# Quận 7              2914
# Quận 9              2777
# Quận 8              2422
# Quận Bình Tân       2165
# Quận Thủ Đức        1988
# Quận 2              1807
# Quận Tân Phú        1462
# Huyện Nhà Bè        1091
# Quận Bình Thạnh      956
# Quận 12              888
# Quận Tân Bình        786
# Huyện Bình Chánh     727
# Quận 6               683
# Quận Phú Nhuận       641
# Quận Gò Vấp          608
# Quận 10              474
# Quận 4               406
# Huyện Hóc Môn        346
# Quận 5               343
# Quận 1               318
# Quận 3               108
# Quận 11               97
# Huyện Củ Chi          12
# Name: count, dtype: int64
